# %% [markdown]
# extract data through api
# location in levels
# how to connect multiple ml models and work
#
# selenium

# %%
levels - debug , INFO , warning , error , criticle

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import logging

for handler in logging.root.handlers[:]:
  logging.root.removeHandler(handler)

logging.basicConfig (              # Saving Severity Level
    level = logging.INFO,
    format = '%(asctime)s | %(levelname)s | %(message)s',
    datefmt = '%Y-%m-%d %H:%M:%S',
    force = True
)
logging.info("Application Started Successfully")

data = {
    "Experience": [1, 2, 3, 4, 5, 6],
    "Salary": [25000, 45000, 60000, 75000, 90000, 105000]
}


df = pd.DataFrame(data)

X = df[["Experience"]]
y = df["Salary"]

logging.info(f"Dataset Shape: {df.shape}")
# Out:
# 2026-07-06 10:42:47 | INFO | Application Started Successfully
# 2026-07-06 10:42:47 | INFO | Dataset Shape: (6, 2)

# %%
model = LinearRegression()
model.fit(X,y)

logging.info(f'Intercept: {model.intercept_}')
logging.info(f'Coefficient: {model.coef_[0]}')

prediction = model.predict([[7]])

logging.info(f'Prediction completed successfully')
print('predicted_salary',prediction[0])

logging.info("Application finished  Successfully")
# Out:
# 2026-07-06 10:42:50 | INFO | Intercept: 11666.666666666657
# 2026-07-06 10:42:50 | INFO | Coefficient: 15714.285714285717
# c:\Users\Dell\anaconda3\envs\myenv\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 2026-07-06 10:42:50 | INFO | Prediction completed successfully
# 2026-07-06 10:42:50 | INFO | Application finished  Successfully
# predicted_salary 121666.66666666669

# %% [markdown]
# # web scrapping -
#
# books to scrap , quotes to scrap : srapping websites
